# %%
from environment import GsyEnv
import click

# %%
from simulationController import SimulationController

# %%
sim_controller = SimulationController()

# %%
sim_controller.start()

# %%
sim_controller.current_market_tree
# Out:
# {'7e08b649-c6d4-4a3a-8fb4-4ef1ac68b0a6': {'last_market_bill': {'accumulated_trades': {'earned': 0.219,
#     'spent': 0.219,
#     'bought': 0.995,
#     'sold': 0.995},
#    'external_trades': {'earned': 0.0,
#     'spent': 0.0,
#     'bought': 0.0,
#     'sold': 0.0}},
#   'last_market_stats': {'min_trade_rate': 26.0,
#    'max_trade_rate': 26.0,
#    'avg_trade_rate': 26.0,
#    'median_trade_rate': 26.0,
#    'total_traded_energy_kWh': 0.298222},
#   'last_market_fee': 4,
#   'current_market_fee': 4,
#   'area_name': 'Grid',
#   'children': {'467f427e-57d7-411e-84cd-7130d787db95': {'last_market_bill': {'accumulated_trades': {'earned': 0.0,
#       'spent': 0.259,
#       'bought': 0.995,
#       'sold': 0.0},
#      'external_trades': {'earned': 0.259,
#       'spent': 0.0,
#       'bought': 0.0,
#       'sold': 0.995}},
#     'last_market_stats': {'min_trade_rate': 30.0,
#      'max_trade_rate': 30.0,
#      'avg_trade_rate': 30.0,
#      'median_trade_rate': 30.0,
#      'total_traded_energy_kWh': 0.298222},
#     'last_market_fee': 4,
#     'current_market_fee': 4,
#     'area_name': 'Community',
#     'children': {'570324a1-4da6-4800-a4f4-2337ebf28c0c': {'last_market_bill': {'accumulated_trades': {'earned': 0.0,
#         'spent': 0.018,
#         'bought': 0.061,
#         'sold': 0.0},
#        'external_trades': {'earned': 0.018,
#         'spent': 0.0,
#         'bought': 0.0,
#         'sold': 0.061}},
#       'last_market_stats': {'min_trade_rate': 30.0,
#        'max_trade_rate': 30.0,
#        'avg_trade_rate': 30.0,
#        'median_trade_rate': 30.0,
#        'total_traded_energy_kWh': 0.0176575},
#       'last_market_fee': 0.0,
#       'current_market_fee': None,
#       'area_name': 'Family 2 children+PV',
#       'children': {'889467a6-187b-4b6d-9afc-11e8d13389af': {'asset_info': {'energy_requirement_kWh': 0.02375,
#          'energy_active_in_bids': 0.02375,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.061,
#          'sold': 0.0,
#          'spent': 0.018,
#          'earned': 0.0,
#          'total_energy': 0.061,
#          'total_cost': 0.018,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 1 L13'},
#        '2af4c92a-13aa-48c9-8188-e795ac0e049e': {'asset_info': {'available_energy_kWh': 0.0,
#          'energy_active_in_offers': 0,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.0,
#          'sold': 0.0,
#          'spent': 0.0,
#          'earned': 0.0,
#          'total_energy': 0.0,
#          'total_cost': 0.0,
#          'market_fee': 0.0,
#          'type': 'PV'},
#         'area_name': 'PV 1 (4kW)'}}},
#      'f63a88c9-d5d7-4593-bbd5-e8bc63251a3a': {'last_market_bill': {'accumulated_trades': {'earned': 0.0,
#         'spent': 0.024,
#         'bought': 0.081,
#         'sold': 0.0},
#        'external_trades': {'earned': 0.024,
#         'spent': 0.0,
#         'bought': 0.0,
#         'sold': 0.081}},
#       'last_market_stats': {'min_trade_rate': 30.0,
#        'max_trade_rate': 30.0,
#        'avg_trade_rate': 30.0,
#        'median_trade_rate': 30.0,
#        'total_traded_energy_kWh': 0.0291665},
#       'last_market_fee': 0.0,
#       'current_market_fee': None,
#       'area_name': 'Family 2 children',
#       'children': {'4c927c50-bc3b-45e4-a6ac-72b92bed35d5': {'asset_info': {'energy_requirement_kWh': 0.01903225,
#          'energy_active_in_bids': 0.01903225,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.081,
#          'sold': 0.0,
#          'spent': 0.024,
#          'earned': 0.0,
#          'total_energy': 0.081,
#          'total_cost': 0.024,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 2 L21'}}},
#      'fc27c747-66c4-4909-b503-6811523076dc': {'last_market_bill': {'accumulated_trades': {'earned': 0.0,
#         'spent': 0.018,
#         'bought': 0.061,
#         'sold': 0.0},
#        'external_trades': {'earned': 0.018,
#         'spent': 0.0,
#         'bought': 0.0,
#         'sold': 0.061}},
#       'last_market_stats': {'min_trade_rate': 30.0,
#        'max_trade_rate': 30.0,
#        'avg_trade_rate': 30.0,
#        'median_trade_rate': 30.0,
#        'total_traded_energy_kWh': 0.02104175},
#       'last_market_fee': 0.0,
#       'current_market_fee': None,
#       'area_name': 'Family 3 children+PV+Batt',
#       'children': {'38e8d782-07b8-47dd-a794-1e584bfbe7c5': {'asset_info': {'energy_requirement_kWh': 0.02885275,
#          'energy_active_in_bids': 0.02885275,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.061,
#          'sold': 0.0,
#          'spent': 0.018,
#          'earned': 0.0,
#          'total_energy': 0.061,
#          'total_cost': 0.018,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 3 L17'},
#        'e0b872e2-739e-40af-8aef-b3a4c9a4740c': {'asset_info': {'available_energy_kWh': 0.0,
#          'energy_active_in_offers': 0,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.0,
#          'sold': 0.0,
#          'spent': 0.0,
#          'earned': 0.0,
#          'total_energy': 0.0,
#          'total_cost': 0.0,
#          'market_fee': 0.0,
#          'type': 'PV'},
#         'area_name': 'PV 3 (5kW)'},
#        '8927c3d8-91bb-4c76-92b5-18fd87c84010': {'asset_info': {'energy_to_sell': -0.0,
#          'energy_active_in_bids': 1.25,
#          'energy_to_buy': 0.0,
#          'energy_active_in_offers': 0,
#          'free_storage': 12.6,
#          'used_storage': 1.4,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.0,
#          'sold': 0.0,
#          'spent': 0.0,
#          'earned': 0.0,
#          'total_energy': 0.0,
#          'total_cost': 0.0,
#          'market_fee': 0.0,
#          'type': 'Storage'},
#         'area_name': 'Tesla Powerwall 3'}}},
#      '8c1105f0-eff9-43cb-b095-8a5bcc628c84': {'last_market_bill': {'accumulated_trades': {'earned': 0.0,
#         'spent': 0.021,
#         'bought': 0.071,
#         'sold': 0.0},
#        'external_trades': {'earned': 0.021,
#         'spent': 0.0,
#         'bought': 0.0,
#         'sold': 0.071}},
#       'last_market_stats': {'min_trade_rate': 30.0,
#        'max_trade_rate': 30.0,
#        'avg_trade_rate': 30.0,
#        'median_trade_rate': 30.0,
#        'total_traded_energy_kWh': 0.01197675},
#       'last_market_fee': 0.0,
#       'current_market_fee': None,
#       'area_name': 'Young Couple',
#       'children': {'25643874-6735-4c6b-a576-01783c842985': {'asset_info': {'energy_requirement_kWh': 0.0338825,
#          'energy_active_in_bids': 0.0338825,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.071,
#          'sold': 0.0,
#          'spent': 0.021,
#          'earned': 0.0,
#          'total_energy': 0.071,
#          'total_cost': 0.021,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 4 L15'}}},
#      '401f16da-c67e-4be9-a110-d4deb495c68b': {'last_market_bill': {'accumulated_trades': {'earned': 0.0,
#         'spent': 0.027,
#         'bought': 0.089,
#         'sold': 0.0},
#        'external_trades': {'earned': 0.027,
#         'spent': 0.0,
#         'bought': 0.0,
#         'sold': 0.089}},
#       'last_market_stats': {'min_trade_rate': 30.0,
#        'max_trade_rate': 30.0,
#        'avg_trade_rate': 30.0,
#        'median_trade_rate': 30.0,
#        'total_traded_energy_kWh': 0.022795},
#       'last_market_fee': 0.0,
#       'current_market_fee': None,
#       'area_name': 'Multigenerational house',
#       'children': {'378d06cd-836c-4f7d-aa94-fe7ae0b83af3': {'asset_info': {'energy_requirement_kWh': 0.025075,
#          'energy_active_in_bids': 0.025075,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.089,
#          'sold': 0.0,
#          'spent': 0.027,
#          'earned': 0.0,
#          'total_energy': 0.089,
#          'total_cost': 0.027,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 5 L9'},
#        'f3ab042e-cdbc-4ed1-80a6-744329016066': {'asset_info': {'available_energy_kWh': 0.0,
#          'energy_active_in_offers': 0,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.0,
#          'sold': 0.0,
#          'spent': 0.0,
#          'earned': 0.0,
#          'total_energy': 0.0,
#          'total_cost': 0.0,
#          'market_fee': 0.0,
#          'type': 'PV'},
#         'area_name': 'PV 5 (10kW)'},
#        '6967c2c2-214e-408e-a22e-7c68beb8d703': {'asset_info': {'energy_to_sell': -0.0,
#          'energy_active_in_bids': 1.25,
#          'energy_to_buy': 0.0,
#          'energy_active_in_offers': 0,
#          'free_storage': 12.6,
#          'used_storage': 1.4,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.0,
#          'sold': 0.0,
#          'spent': 0.0,
#          'earned': 0.0,
#          'total_energy': 0.0,
#          'total_cost': 0.0,
#          'market_fee': 0.0,
#          'type': 'Storage'},
#         'area_name': 'Tesla Powerwall 5'}}},
#      '39e2aeae-656e-44d8-9e8f-44bbb6ab0f94': {'last_market_bill': {'accumulated_trades': {'earned': 0.0,
#         'spent': 0.015,
#         'bought': 0.05,
#         'sold': 0.0},
#        'external_trades': {'earned': 0.015,
#         'spent': 0.0,
#         'bought': 0.0,
#         'sold': 0.05}},
#       'last_market_stats': {'min_trade_rate': 30.0,
#        'max_trade_rate': 30.0,
#        'avg_trade_rate': 30.0,
#        'median_trade_rate': 30.0,
#        'total_traded_energy_kWh': 0.013772},
#       'last_market_fee': 0.0,
#       'current_market_fee': None,
#       'area_name': 'Retired couple',
#       'children': {'913c1d15-53c8-4a7f-a9e2-66adaac2b314': {'asset_info': {'energy_requirement_kWh': 0.0237115,
#          'energy_active_in_bids': 0.0237115,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.05,
#          'sold': 0.0,
#          'spent': 0.015,
#          'earned': 0.0,
#          'total_energy': 0.05,
#          'total_cost': 0.015,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 6 L24'}}},
#      '25913db4-7f7e-40a5-99ad-93c84e9669aa': {'last_market_bill': {'accumulated_trades': {'earned': 0.0,
#         'spent': 0.018,
#         'bought': 0.06,
#         'sold': 0.0},
#        'external_trades': {'earned': 0.018,
#         'spent': 0.0,
#         'bought': 0.0,
#         'sold': 0.06}},
#       'last_market_stats': {'min_trade_rate': 30.0,
#        'max_trade_rate': 30.0,
#        'avg_trade_rate': 30.0,
#        'median_trade_rate': 30.0,
#        'total_traded_energy_kWh': 0.016396},
#       'last_market_fee': 0.0,
#       'current_market_fee': None,
#       'area_name': 'Flatsharing Student',
#       'children': {'2bf8556c-6b35-4040-beb4-06010294838d': {'asset_info': {'energy_requirement_kWh': 0.01624975,
#          'energy_active_in_bids': 0.01624975,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.06,
#          'sold': 0.0,
#          'spent': 0.018,
#          'earned': 0.0,
#          'total_energy': 0.06,
#          'total_cost': 0.018,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 7 L22'}}},
#      '02a299ff-9f0b-43a6-a2b5-30fce6d7a263': {'last_market_bill': {'accumulated_trades': {'earned': 0.0,
#         'spent': 0.078,
#         'bought': 0.261,
#         'sold': 0.0},
#        'external_trades': {'earned': 0.078,
#         'spent': 0.0,
#         'bought': 0.0,
#         'sold': 0.261}},
#       'last_market_stats': {'min_trade_rate': 30.0,
#        'max_trade_rate': 30.0,
#        'avg_trade_rate': 30.0,
#        'median_trade_rate': 30.0,
#        'total_traded_energy_kWh': 0.08270825},
#       'last_market_fee': 0.0,
#       'current_market_fee': None,
#       'area_name': '6 apartments building',
#       'children': {'4b53c9ee-c396-4966-86b9-5b36e14a9f38': {'asset_info': {'energy_requirement_kWh': 0.01044825,
#          'energy_active_in_bids': 0.01044825,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.044,
#          'sold': 0.0,
#          'spent': 0.013,
#          'earned': 0.0,
#          'total_energy': 0.044,
#          'total_cost': 0.013,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 81 L20'},
#        'f6185994-bd59-4b09-b6c9-fef545d4a189': {'asset_info': {'energy_requirement_kWh': 0.014362999999999999,
#          'energy_active_in_bids': 0.014362999999999999,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.053,
#          'sold': 0.0,
#          'spent': 0.016,
#          'earned': 0.0,
#          'total_energy': 0.053,
#          'total_cost': 0.016,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 82 L17'},
#        '00adbf08-b6e6-49ab-8b72-c1efd3227ec4': {'asset_info': {'energy_requirement_kWh': 0.0115415,
#          'energy_active_in_bids': 0.0115415,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.034,
#          'sold': 0.0,
#          'spent': 0.01,
#          'earned': 0.0,
#          'total_energy': 0.034,
#          'total_cost': 0.01,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 83 L14'},
#        '4f39bc9a-1c19-45c6-8343-831df2baa613': {'asset_info': {'energy_requirement_kWh': 0.0038635,
#          'energy_active_in_bids': 0.0038635,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.021,
#          'sold': 0.0,
#          'spent': 0.006,
#          'earned': 0.0,
#          'total_energy': 0.021,
#          'total_cost': 0.006,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 84 L10'},
#        '0755a046-13dd-475b-b8fe-231894192660': {'asset_info': {'energy_requirement_kWh': 0.01624975,
#          'energy_active_in_bids': 0.01624975,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.06,
#          'sold': 0.0,
#          'spent': 0.018,
#          'earned': 0.0,
#          'total_energy': 0.06,
#          'total_cost': 0.018,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 85 L22'},
#        'd169f64c-2bd8-4ac5-8698-b1949280a83f': {'asset_info': {'energy_requirement_kWh': 0.01346325,
#          'energy_active_in_bids': 0.01346325,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.049,
#          'sold': 0.0,
#          'spent': 0.015,
#          'earned': 0.0,
#          'total_energy': 0.049,
#          'total_cost': 0.015,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 86 L8'}}},
#      '9e5b5a13-2589-42c6-8796-113962b5b5e0': {'last_market_bill': {'accumulated_trades': {'earned': 0.0,
#         'spent': 0.078,
#         'bought': 0.261,
#         'sold': 0.0},
#        'external_trades': {'earned': 0.078,
#         'spent': 0.0,
#         'bought': 0.0,
#         'sold': 0.261}},
#       'last_market_stats': {'min_trade_rate': 30.0,
#        'max_trade_rate': 30.0,
#        'avg_trade_rate': 30.0,
#        'median_trade_rate': 30.0,
#        'total_traded_energy_kWh': 0.08270825},
#       'last_market_fee': 0.0,
#       'current_market_fee': None,
#       'area_name': '6 apartments building+PV',
#       'children': {'bcac0d09-8804-4aa3-bffa-3c6b247d9e10': {'asset_info': {'energy_requirement_kWh': 0.01044825,
#          'energy_active_in_bids': 0.01044825,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.044,
#          'sold': 0.0,
#          'spent': 0.013,
#          'earned': 0.0,
#          'total_energy': 0.044,
#          'total_cost': 0.013,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 81 L20'},
#        '46fc57e4-caef-4798-acc1-5809dd1111f3': {'asset_info': {'energy_requirement_kWh': 0.014362999999999999,
#          'energy_active_in_bids': 0.014362999999999999,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.053,
#          'sold': 0.0,
#          'spent': 0.016,
#          'earned': 0.0,
#          'total_energy': 0.053,
#          'total_cost': 0.016,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 82 L17'},
#        'a4a03abe-b303-425b-88a6-f2eceeb91660': {'asset_info': {'energy_requirement_kWh': 0.0115415,
#          'energy_active_in_bids': 0.0115415,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.034,
#          'sold': 0.0,
#          'spent': 0.01,
#          'earned': 0.0,
#          'total_energy': 0.034,
#          'total_cost': 0.01,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 83 L14'},
#        '8d1d3cd1-5634-4141-9dee-d323e3c41c78': {'asset_info': {'energy_requirement_kWh': 0.0038635,
#          'energy_active_in_bids': 0.0038635,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.021,
#          'sold': 0.0,
#          'spent': 0.006,
#          'earned': 0.0,
#          'total_energy': 0.021,
#          'total_cost': 0.006,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 84 L10'},
#        'cc65e78b-f4a1-41fa-96d6-0120a76f6589': {'asset_info': {'energy_requirement_kWh': 0.01624975,
#          'energy_active_in_bids': 0.01624975,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.06,
#          'sold': 0.0,
#          'spent': 0.018,
#          'earned': 0.0,
#          'total_energy': 0.06,
#          'total_cost': 0.018,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 85 L22'},
#        'bcd0a31e-6ba4-40d0-9dc0-187c73a27008': {'asset_info': {'energy_requirement_kWh': 0.01346325,
#          'energy_active_in_bids': 0.01346325,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.049,
#          'sold': 0.0,
#          'spent': 0.015,
#          'earned': 0.0,
#          'total_energy': 0.049,
#          'total_cost': 0.015,
#          'market_fee': 0.0,
#          'type': 'Load'},
#         'area_name': 'Load 86 L8'},
#        '7a843e54-c2d2-49d0-8a75-85a7ea15246b': {'asset_info': {'available_energy_kWh': 0.0,
#          'energy_active_in_offers': 0,
#          'energy_traded': 0,
#          'total_cost': 0},
#         'last_slot_asset_info': {'energy_traded': 0, 'total_cost': 0},
#         'asset_bill': {'bought': 0.0,
#          'sold': 0.0,
#          'spent': 0.0,
#          'earned': 0.0,
#          'total_energy': 0.0,
#          'total_cost': 0.0,
#          'market_fee': 0.0,
#          'type': 'PV'},
#         'area_name': 'PV 9 (15kW)'}}}}},
#    '1c8f3930-eb69-450e-9ed9-ce3ae4f11207': {'area_name': 'Market Maker'}}}}
# CRITICAL:gsy_e.gsy_e_core.simulation:Simulation resumed
# ERROR:gsy_e.gsy_e_core.simulation:Received stop command for configuration id  and job id None.

# %%
sim_controller.next_slot()
# Out:
# CRITICAL:gsy_e.gsy_e_core.simulation:Simulation resumed
# WARNING:gsy_e.gsy_e_core.simulation:Slot 5 of 96 - (5.2 %) 43 seconds elapsed, ETA: 13 minutes 11 seconds
# CRITICAL:gsy_e.gsy_e_core.simulation:Simulation paused. Press 'p' to resume or resume from API.

# %%
sim_controller.slot_number

# %%
from gsy_e.gsy_e_core.global_objects_singleton import global_objects

# %%
sim_controller.register_asset("PV 9 (15kW)")

# %%
sim_controller.shared_object["simulation"]

# %%
import json

# %%
import redis
r = redis.StrictRedis(host='localhost', port=6379, db=0, decode_responses=True)

# %%
area_dict = json.loads(area_to_string(area))

# %%
area_to_string(area)

# %%
r.publish("/live-event", json.dumps({"transaction_id": str(12312),"eventType":"create_area", "transaction_id":1, "parent_uuid":"", "area_representation":area_dict}))

# %%
json.loads(json.dumps(area,cls=AreaEncoder))

# %%
json.loads(area_to_string(area))

# %%
import redis
redis = redis.StrictRedis(host='localhost', port=6379, db=0, decode_responses=True)

# %%
sim_controller.resume()

# %%
sim_controller.register_asset("Load 82 L17")

# %%
env = GsyEnv()

# %%
env.reset()

# %%
thread = threading.Thread(target=gsy_cli.main, args=(["-l", "INFO", "run", "-t", "5s", "-s", "15m", "--setup", "api_setup.default_community", "--enable-external-connection", "--paused", "--slot-length-realtime", "10"],))x

# %%
cli.main(['--setup', 'redis_basic_strategies_BC.py', '--run-on-redis', '--base-setup-path', ''])

# %%
thread.start()

# %%
sc.resume_simulation()

# %%
print("0")

# %%
simulation = object_shared["simulation"]

# %%
simulation._status.toggle_pause()
